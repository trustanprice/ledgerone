# %% [markdown]
# # Event Sanity Checks
#
# This notebook contains sanity checks and exploratory queries used to validate the randomly generated financial event data for the LedgerOne project. The goal is to ensure data correctness and consistency before transforming events into ledger entries.

# %%
# Call 1: Setup

from pathlib import Path
import duckdb
import pandas as pd

PROJECT_ROOT = Path("/Users/trustanprice/Desktop/Personal/ledgerone")
DB_PATH = PROJECT_ROOT / "data/processed/ledgerone.duckdb"

DATA_DIR = Path("/Users/trustanprice/Desktop/Personal/ledgerone/data/raw/")

EVENTS_PATH = DATA_DIR / "events.parquet"
USERS_PATH = DATA_DIR / "users.parquet"
ACCOUNTS_PATH = DATA_DIR / "accounts.parquet"

con = duckdb.connect()

# %%
# Cell 2: Load & inspect events
con.execute(f"""
  SELECT event_type, direction, COUNT(*) AS cnt
  FROM read_parquet('{EVENTS_PATH}')
  GROUP BY 1, 2
  ORDER BY 1, 2
""").df()
# Out:
#   event_type direction  cnt
# 0    DEPOSIT    CREDIT  100
# 1        FEE     DEBIT  313
# 2   PURCHASE     DEBIT  313
# 3     REFUND    CREDIT   30

# %%
# Cell 3: Spot-check refunds
con.execute(f"""
  SELECT *
  FROM read_parquet('{EVENTS_PATH}')
  WHERE event_type = 'REFUND'
  LIMIT 10
""").df()
# Out:
#                                event_id            event_ts  \
# 0  42174ec8-6d85-4106-8096-4ea7a0b0e0b2 2024-01-24 05:28:22
# 1  93e533b5-6d46-4987-8204-7eddf45bc833 2024-03-29 14:50:39
# 2  c25dc2e3-faf7-49f6-aaec-50baad392d4c 2024-03-27 12:33:44
# 3  3c1ef7be-23eb-437f-b3ef-eb71d8d5a951 2024-01-06 06:43:46
# 4  73827635-81dd-4a4a-8374-21b4095372d4 2024-02-25 11:00:27
# 5  125667ed-df22-44ec-82c8-2d3202f880f9 2024-02-23 23:19:03
# 6  4b93bd3a-e7e1-4da7-b3e4-1a1e2211fe4c 2024-01-23 15:26:58
# 7  8811e3a5-aff2-4dc6-9c26-182f851a808f 2024-03-25 22:05:18
# 8  3008bf55-0b2f-481a-9718-b6c15de8c635 2024-01-26 17:32:47
# 9  be7b3fad-2ca3-4bef-b5c6-1204c1edb477 2024-03-05 23:14:00
#
#                                 user_id                            account_id  \
# 0  b5ccbe19-156a-4d12-a902-e0c6baca5469  470c6691-607a-44cc-9d3b-b06bf2db2016
# 1  e29a0f67-376c-4787-8399-2c7204af61af  9daa1912-6053-4836-b590-23068015e693
# 2  32aea6a2-c7b8-4900-aa45-a6de114dda60  0f35fb82-36d6-4e74-abfb-477ab980c433
# 3  9d110828-2021-4f85-aafb-bae994036bd2  96cff856-3eb1-48a7-a0a2-89555152a290
# 4  882a146c-609a-41b0-b909-f866847d9706  08f3bd55-a114-4fdb-94a9-e60708f644df
# 5  882a146c-609a-41b0-b909-f866847d9706  08f3bd55-a114-4fdb-94a9-e60708f644df
# 6  79351d33-af16-4c9d-b5fe-3cd8d64cd129  206d8f8f-405e-468d-96d5-2e062b87e89d
# 7  24cda416-69bd-4c57-9547-28c36fb69a59  42b9ce85-190f-4c65-b86b-b317771819d5
# 8  3b48b586-531d-48f8-af77-d3939eee7281  ce73e887-88c5-4d58-b1e5-1f1ea8850fbf
# 9  aca2844e-b1a2-4164-8afb-2778a7eacc29  c6614a39-20e4-4557-84e9-9223aee1ffdf
#
#   event_type direction  amount currency                          reference_id
# 0     REFUND    CREDIT    10.0      USD  c39f7b3a-dde2-4edd-9c2d-1f44215ab451
# 1     REFUND    CREDIT    25.0      USD  4c1e6cc7-d5a4-4390-a56e-98a960a78fa7
# 2     REFUND    CREDIT    20.0      USD  c28303f0-cae9-4110-87d4-0a5ffff502de
# 3     REFUND    CREDIT    20.0      USD  59aa9d7b-f4a9-4c11-850d-7749a09bd6e8
# 4     REFUND    CREDIT    25.0      USD  e92ef2fb-044f-48b3-b8cc-7bc7c860ed02
# 5     REFUND    CREDIT    15.0      USD  4a520abf-1241-46d1-8e28-b4f09d44d3e0
# 6     REFUND    CREDIT    15.0      USD  0003a08e-2aeb-420d-bb53-3ed654a49ae1
# 7     REFUND    CREDIT    20.0      USD  f8879e0b-d3af-442e-8173-e83b27bfbd91
# 8     REFUND    CREDIT    15.0      USD  652ce229-a360-4419-b32a-01b197b9ff53
# 9     REFUND    CREDIT    15.0      USD  d7ee8a60-def5-46d0-bd8a-49bf5aa053a8

# %%
# Cell 4: Check amounts are always positive
con.execute(f"""
  SELECT COUNT(*) AS negative_amounts
  FROM read_parquet('{EVENTS_PATH}')
  WHERE amount <= 0
""").df()
# Out:
#    negative_amounts
# 0                 0

# %%
# Cell 5: Confirm the dbt-built ledger (main_staging.stg_ledger_entries)
# matches the raw event count. The ledger is now built by `dbt build`
# (see dbt/models/staging/stg_ledger_entries.sql) rather than by executing
# sql/ledger.sql directly — run `make build` first if this errors.
con = duckdb.connect(str(DB_PATH), read_only=True)

rows = con.execute("SELECT COUNT(*) FROM main_staging.stg_ledger_entries").fetchone()[0]
print("stg_ledger_entries rows:", rows)

con.close()
# Out:
# stg_ledger_entries rows: 756
